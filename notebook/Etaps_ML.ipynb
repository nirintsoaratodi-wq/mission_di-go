# %% [markdown]
# ## **ETAPES CLES D'UN PROJET DE MACHINE LEARNING**
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1️⃣ **Définition du problème**
# - Quel est l’objectif ?\
# Prédire ?\
# Classifier ?\
# Regrouper ?
# - Quelle est la variable cible (target) ?
# ## 2️⃣ **Collection des données (Data Collection)**
# 👉 **Sources possibles** :\
# - Fichiers CSV / Excel
# - Bases de données
# - API
# - Capteurs / enquêtes
# ## **3️⃣ Compréhension & exploration des données (EDA)**
# 👉 **Même avec PyCaret, cette étape est obligatoire Structure des données**
# - Types de variables
# - Valeurs manquantes
# - Corrélations
# - Visualisations\
# 📌 Objectif :\
# ➡️ comprendre la qualité des données avant ``setup()``
